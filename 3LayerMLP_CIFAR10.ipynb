# %% [markdown]
# <a href="https://colab.research.google.com/github/paolotuazon26/Advanced-Deep-Learning-with-Keras/blob/master/3LayerMLP_CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# With early stopping, 54.9% 
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.utils import to_categorical, plot_model
from keras.datasets import cifar10
from keras import optimizers
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from matplotlib import pyplot


# load CIFAR10 Data set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
no_classes = 10

labels = len(np.unique(y_train))


y_train = to_categorical(y_train, no_classes)
y_test = to_categorical(y_test, no_classes)

# image dimensions (assumed square), RGB 
image_size = x_train.shape[1]
input_size = image_size * image_size * 3 

# resize and normalize

x_train = x_train.reshape(50000, 32 * 32 * 3)
x_test = x_test.reshape(10000, 32 * 32 * 3)

x_train = x_train.astype('float32') / 255

x_test = x_test.astype('float32') / 255

# network parameters
batch_size = 64
dropout = 0.2

# model is a 3-layer MLP with ReLU and dropout after each layer
model = Sequential()
model.add(Dense(1024, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(num_labels))
# this is the output for one-hot vector
model.add(Activation('softmax'))
model.summary()
#plot_model(model, to_file='mlp-mnist.png', show_shapes=True)

# loss function for one-hot vector
# use of sgd optimizer with default lr=0.01
# accuracy is good metric for classification tasks
sgd = optimizers.SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
# train the network
# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='auto', verbose=1, patience = 5)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)


# fit model
history = model.fit(x_train, y_train, validation_split=0.2, epochs=500, batch_size = batch_size,  verbose=1, callbacks=[es,mc])

saved_model = load_model('best_model.h5')
# evaluate the model
loss_train, train_acc = model.evaluate(x_train, y_train, verbose=0)
loss_test, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Train: %.1f%%, Test: %.1f%%' % (100*train_acc, 100*test_acc))
# plot training history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# validate the model on test dataset to determine generalization
##loss, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
##print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_144 (Dense)            (None, 1024)              3146752
# _________________________________________________________________
# activation_143 (Activation)  (None, 1024)              0
# _________________________________________________________________
# dropout_96 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_145 (Dense)            (None, 512)               524800
# _________________________________________________________________
# activation_144 (Activation)  (None, 512)               0
# _________________________________________________________________
# dropout_97 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_146 (Dense)            (None, 10)                5130
# _________________________________________________________________
# activation_145 (Activation)  (None, 10)                0
# =================================================================
# Total params: 3,676,682
# Trainable params: 3,676,682
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/500
# 40000/40000 [==============================] - 10s 252us/step - loss: 1.9717 - acc: 0.2920 - val_loss: 1.8079 - val_acc: 0.3690
#
# Epoch 00001: val_acc improved from -inf to 0.36900, saving model to best_model.h5
# Epoch 2/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.7944 - acc: 0.3644 - val_loss: 1.7372 - val_acc: 0.3924
#
# Epoch 00002: val_acc improved from 0.36900 to 0.39240, saving model to best_model.h5
# Epoch 3/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.7199 - acc: 0.3953 - val_loss: 1.6883 - val_acc: 0.4099
#
# Epoch 00003: val_acc improved from 0.39240 to 0.40990, saving model to best_model.h5
# Epoch 4/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.6709 - acc: 0.4113 - val_loss: 1.6626 - val_acc: 0.4085
#
# Epoch 00004: val_acc did not improve from 0.40990
# Epoch 5/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.6295 - acc: 0.4258 - val_loss: 1.6040 - val_acc: 0.4345
#
# Epoch 00005: val_acc improved from 0.40990 to 0.43450, saving model to best_model.h5
# Epoch 6/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.5996 - acc: 0.4350 - val_loss: 1.5732 - val_acc: 0.4470
#
# Epoch 00006: val_acc improved from 0.43450 to 0.44700, saving model to best_model.h5
# Epoch 7/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.5683 - acc: 0.4459 - val_loss: 1.5587 - val_acc: 0.4490
#
# Epoch 00007: val_acc improved from 0.44700 to 0.44900, saving model to best_model.h5
# Epoch 8/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.5447 - acc: 0.4559 - val_loss: 1.5660 - val_acc: 0.4468
#
# Epoch 00008: val_acc did not improve from 0.44900
# Epoch 9/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.5234 - acc: 0.4623 - val_loss: 1.5304 - val_acc: 0.4712
#
# Epoch 00009: val_acc improved from 0.44900 to 0.47120, saving model to best_model.h5
# Epoch 10/500
# 40000/40000 [==============================] - 5s 131us/step - loss: 1.5052 - acc: 0.4687 - val_loss: 1.5106 - val_acc: 0.4710
#
# Epoch 00010: val_acc did not improve from 0.47120
# Epoch 11/500
# 40000/40000 [==============================] - 5s 131us/step - loss: 1.4819 - acc: 0.4782 - val_loss: 1.4961 - val_acc: 0.4750
#
# Epoch 00011: val_acc improved from 0.47120 to 0.47500, saving model to best_model.h5
# Epoch 12/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.4645 - acc: 0.4834 - val_loss: 1.4929 - val_acc: 0.4747
#
# Epoch 00012: val_acc did not improve from 0.47500
# Epoch 13/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.4477 - acc: 0.4869 - val_loss: 1.4699 - val_acc: 0.4842
#
# Epoch 00013: val_acc improved from 0.47500 to 0.48420, saving model to best_model.h5
# Epoch 14/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.4298 - acc: 0.4943 - val_loss: 1.4798 - val_acc: 0.4774
#
# Epoch 00014: val_acc did not improve from 0.48420
# Epoch 15/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.4141 - acc: 0.5010 - val_loss: 1.4479 - val_acc: 0.4929
#
# Epoch 00015: val_acc improved from 0.48420 to 0.49290, saving model to best_model.h5
# Epoch 16/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.4028 - acc: 0.5078 - val_loss: 1.4332 - val_acc: 0.4969
#
# Epoch 00016: val_acc improved from 0.49290 to 0.49690, saving model to best_model.h5
# Epoch 17/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.3885 - acc: 0.5104 - val_loss: 1.4204 - val_acc: 0.4990
#
# Epoch 00017: val_acc improved from 0.49690 to 0.49900, saving model to best_model.h5
# Epoch 18/500
# 40000/40000 [==============================] - 5s 131us/step - loss: 1.3724 - acc: 0.5170 - val_loss: 1.4405 - val_acc: 0.4960
#
# Epoch 00018: val_acc did not improve from 0.49900
# Epoch 19/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.3592 - acc: 0.5226 - val_loss: 1.4162 - val_acc: 0.5020
#
# Epoch 00019: val_acc improved from 0.49900 to 0.50200, saving model to best_model.h5
# Epoch 20/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.3456 - acc: 0.5252 - val_loss: 1.4463 - val_acc: 0.4910
#
# Epoch 00020: val_acc did not improve from 0.50200
# Epoch 21/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.3321 - acc: 0.5294 - val_loss: 1.3992 - val_acc: 0.5074
#
# Epoch 00021: val_acc improved from 0.50200 to 0.50740, saving model to best_model.h5
# Epoch 22/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.3203 - acc: 0.5341 - val_loss: 1.4091 - val_acc: 0.5013
#
# Epoch 00022: val_acc did not improve from 0.50740
# Epoch 23/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.3106 - acc: 0.5384 - val_loss: 1.3791 - val_acc: 0.5161
#
# Epoch 00023: val_acc improved from 0.50740 to 0.51610, saving model to best_model.h5
# Epoch 24/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2979 - acc: 0.5419 - val_loss: 1.3920 - val_acc: 0.5117
#
# Epoch 00024: val_acc did not improve from 0.51610
# Epoch 25/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2866 - acc: 0.5467 - val_loss: 1.3757 - val_acc: 0.5195
#
# Epoch 00025: val_acc improved from 0.51610 to 0.51950, saving model to best_model.h5
# Epoch 26/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2735 - acc: 0.5500 - val_loss: 1.3587 - val_acc: 0.5266
#
# Epoch 00026: val_acc improved from 0.51950 to 0.52660, saving model to best_model.h5
# Epoch 27/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2638 - acc: 0.5550 - val_loss: 1.3641 - val_acc: 0.5232
#
# Epoch 00027: val_acc did not improve from 0.52660
# Epoch 28/500
# 40000/40000 [==============================] - 5s 131us/step - loss: 1.2475 - acc: 0.5599 - val_loss: 1.3616 - val_acc: 0.5219
#
# Epoch 00028: val_acc did not improve from 0.52660
# Epoch 29/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2413 - acc: 0.5617 - val_loss: 1.3701 - val_acc: 0.5229
#
# Epoch 00029: val_acc did not improve from 0.52660
# Epoch 30/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.2364 - acc: 0.5625 - val_loss: 1.3864 - val_acc: 0.5160
#
# Epoch 00030: val_acc did not improve from 0.52660
# Epoch 31/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2235 - acc: 0.5685 - val_loss: 1.3424 - val_acc: 0.5310
#
# Epoch 00031: val_acc improved from 0.52660 to 0.53100, saving model to best_model.h5
# Epoch 32/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.2122 - acc: 0.5695 - val_loss: 1.4278 - val_acc: 0.5112
#
# Epoch 00032: val_acc did not improve from 0.53100
# Epoch 33/500
# 40000/40000 [==============================] - 5s 128us/step - loss: 1.2028 - acc: 0.5731 - val_loss: 1.3495 - val_acc: 0.5294
#
# Epoch 00033: val_acc did not improve from 0.53100
# Epoch 34/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1896 - acc: 0.5802 - val_loss: 1.3693 - val_acc: 0.5205
#
# Epoch 00034: val_acc did not improve from 0.53100
# Epoch 35/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.1837 - acc: 0.5821 - val_loss: 1.3329 - val_acc: 0.5349
#
# Epoch 00035: val_acc improved from 0.53100 to 0.53490, saving model to best_model.h5
# Epoch 36/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.1724 - acc: 0.5853 - val_loss: 1.3293 - val_acc: 0.5351
#
# Epoch 00036: val_acc improved from 0.53490 to 0.53510, saving model to best_model.h5
# Epoch 37/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.1660 - acc: 0.5887 - val_loss: 1.3698 - val_acc: 0.5233
#
# Epoch 00037: val_acc did not improve from 0.53510
# Epoch 38/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1452 - acc: 0.5952 - val_loss: 1.3540 - val_acc: 0.5317
#
# Epoch 00038: val_acc did not improve from 0.53510
# Epoch 39/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1395 - acc: 0.5984 - val_loss: 1.3464 - val_acc: 0.5325
#
# Epoch 00039: val_acc did not improve from 0.53510
# Epoch 40/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1368 - acc: 0.5989 - val_loss: 1.3835 - val_acc: 0.5264
#
# Epoch 00040: val_acc did not improve from 0.53510
# Epoch 41/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1265 - acc: 0.6029 - val_loss: 1.3240 - val_acc: 0.5381
#
# Epoch 00041: val_acc improved from 0.53510 to 0.53810, saving model to best_model.h5
# Epoch 42/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1148 - acc: 0.6061 - val_loss: 1.3178 - val_acc: 0.5439
#
# Epoch 00042: val_acc improved from 0.53810 to 0.54390, saving model to best_model.h5
# Epoch 43/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.1062 - acc: 0.6095 - val_loss: 1.3598 - val_acc: 0.5329
#
# Epoch 00043: val_acc did not improve from 0.54390
# Epoch 44/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.0937 - acc: 0.6145 - val_loss: 1.3146 - val_acc: 0.5455
#
# Epoch 00044: val_acc improved from 0.54390 to 0.54550, saving model to best_model.h5
# Epoch 45/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.0878 - acc: 0.6182 - val_loss: 1.3175 - val_acc: 0.5408
#
# Epoch 00045: val_acc did not improve from 0.54550
# Epoch 46/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.0788 - acc: 0.6195 - val_loss: 1.3829 - val_acc: 0.5299
#
# Epoch 00046: val_acc did not improve from 0.54550
# Epoch 47/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.0684 - acc: 0.6223 - val_loss: 1.3142 - val_acc: 0.5482
#
# Epoch 00047: val_acc improved from 0.54550 to 0.54820, saving model to best_model.h5
# Epoch 48/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.0636 - acc: 0.6231 - val_loss: 1.2985 - val_acc: 0.5504
#
# Epoch 00048: val_acc improved from 0.54820 to 0.55040, saving model to best_model.h5
# Epoch 49/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.0555 - acc: 0.6266 - val_loss: 1.3070 - val_acc: 0.5522
#
# Epoch 00049: val_acc improved from 0.55040 to 0.55220, saving model to best_model.h5
# Epoch 50/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.0462 - acc: 0.6297 - val_loss: 1.3443 - val_acc: 0.5382
#
# Epoch 00050: val_acc did not improve from 0.55220
# Epoch 51/500
# 40000/40000 [==============================] - 5s 130us/step - loss: 1.0319 - acc: 0.6344 - val_loss: 1.3228 - val_acc: 0.5381
#
# Epoch 00051: val_acc did not improve from 0.55220
# Epoch 52/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.0307 - acc: 0.6366 - val_loss: 1.3230 - val_acc: 0.5438
#
# Epoch 00052: val_acc did not improve from 0.55220
# Epoch 53/500
# 40000/40000 [==============================] - 5s 129us/step - loss: 1.0202 - acc: 0.6404 - val_loss: 1.3127 - val_acc: 0.5495
#
# Epoch 00053: val_acc did not improve from 0.55220
# Epoch 00053: early stopping
# Train: 67.0%, Test: 54.9%
